# %%
# %matplotlib inline

# %%
import pandas as pd
import pickle
import matplotlib
import re
from textblob import TextBlob

# %%
# !pwd

# %%
# !ls

# %%
with open('Sep22toOct22.pkl','rb') as f:
    data=pickle.load(f)

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#                                                 author  \
# 0                                           Sean Wolfe
# 1                                          Varada Bhat
# 2                                           Dave Smith
# 3                                          Varada Bhat
# 4                                           Dave Smith
# 5                                          Kif Leswing
# 6                                           Dave Smith
# 7                                  Antonio Villas-Boas
# 8                                             Dami Lee
# 9                                     Cameron Faulkner
# 10                                        Shannon Liao
# 11                                       James Vincent
# 12                                        Paige Leskin
# 13                                 Valentina Palladino
# 14                                         Kif Leswing
# 15                                         Kif Leswing
# ...

# %%
data.drop(['author','url','urlToImage'],axis=1)
# Out:
#                                                content  \
# 0    One of the most groan-worthy features with mod...
# 1    Apple's stock price is at an attractive entry ...
# 2    The iPhone XS and XS Max both feature the same...
# 3    Drew Angerer/Getty Images Apple's stock price ...
# 4    Your phone screen is important. It's the main ...
# 5    Demand for the larger and more expensive iPhon...
# 6    Price is probably the biggest consideration fo...
# 7    Apple is rolling out an update for iOS 12 devi...
# 8    Some new iPhone XS and XS Max buyers have repo...
# 9    Last week was Apple’s time to shine with the i...
# 10   Apple’s parental controls in iOS 12 are rather...
# 11   The big selling point for the Pixel phones has...
# 12   People have found a new way to send gross, unw...
# 13   Enlarge / The iPhone X in space gray (left) co...
# 14   Google pays Apple so that it remains the defau...
# 15   Most people don't think of Apple stores as a g...
# ...

# %%
data.set_index('publishedAt')
# Out:
#                                                                  author  \
# publishedAt
# 2018-10-16T21:01:56Z                                         Sean Wolfe
# 2018-10-08T15:00:00Z                                        Varada Bhat
# 2018-10-16T14:52:06Z                                         Dave Smith
# 2018-10-08T15:00:00Z                                        Varada Bhat
# 2018-10-21T12:00:00Z                                         Dave Smith
# 2018-09-24T17:33:28Z                                        Kif Leswing
# 2018-10-06T13:30:00Z                                         Dave Smith
# 2018-10-08T17:47:23Z                                Antonio Villas-Boas
# 2018-10-01T18:18:46Z                                           Dami Lee
# 2018-09-22T15:00:02Z                                   Cameron Faulkner
# 2018-10-18T19:14:12Z                                       Shannon Liao
# 2018-10-09T16:18:50Z                                      James Vincent
# ...

# %%
content=[]
desc=[]
title=[]

# %%
for index,row in data.iterrows():
    content.append(row['content'])
    desc.append(row['description'])
    title.append(row['title'])

# %%
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/) \$")

# %%
def preprocess(reviews):
    reviews = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews if line]
    reviews = [REPLACE_WITH_SPACE.sub(" ", line.lower()) for line in reviews if line]
    
    return reviews

# %%
content=preprocess(content)
desc=preprocess(desc)
title=preprocess(title)

# %%
print(len(content),len(content),len(content))
# Out:
# 888 888 888

# %%
for key,val in enumerate(content):
    wiki=TextBlob(val)
    print(wiki.sentiment[0])
# Out:
# 0.2816666666666666
# 0.31212121212121213
# 0.12916666666666665
# 0.4681818181818182
# 0.35
# -0.0017045454545454551
# 0.25
# 0.016666666666666666
# 0.07878787878787878
# 0.09999999999999999
# 0.075
# 0.05454545454545454
# 0.14393939393939392
# 0.14714285714285716
# 0.5
# 0.4720000000000001
# 0.2081439393939394
# 0.125
# 0.03333333333333333
# 0.24
# 0.2903409090909091
# 0.16818181818181818
# 0.25757575757575757
# 0.06818181818181818
# 0.05
# 0.053282828282828286
# 0.22083333333333335
# -0.01666666666666667
# -0.03333333333333333
# 0.21212121212121213
# -0.023809523809523808
# 0.17012987012987013
# 0.21666666666666667
# 0.31746031746031744
# 0.17714285714285713
# 0.11666666666666665
# 0.2425
# 0.0
# 0.1875
# 0.0
# 0.18409090909090908
# 0.3666666666666667
# 0.06818181818181818
# 0.19999999999999998
# 0.38393939393939397
# 0.0
# 0.29333333333333333
# 0.1
# -0.07
# 0.09999999999999998
# 0.25
# 0.7
# 0.25
# 0.1721981721981722
# -0.033333333333333326
# -0.02500000000000001
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of                                                 author  \
# 0                                           Sean Wolfe
# 1                                          Varada Bhat
# 2                                           Dave Smith
# 3                                          Varada Bhat
# 4                                           Dave Smith
# 5                                          Kif Leswing
# 6                                           Dave Smith
# 7                                  Antonio Villas-Boas
# 8                                             Dami Lee
# 9                                     Cameron Faulkner
# 10                                        Shannon Liao
# 11                                       James Vincent
# 12                                        Paige Leskin
# 13                                 Valentina Palladino
# 14                                         Kif Leswing
# ...

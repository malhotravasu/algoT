# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv("5min_SBIN_md.csv", parse_dates=['timestamp']).sort_values('timestamp').set_index('timestamp')

# %%
df['close'].loc['2018-6-8'].rolling(5).mean().plot()
df['close'].loc['2018-6-8'].rolling(15).mean().plot()

# %%
df['close'].plot()
df['slope'] = df['close'].diff()
df['slope'].plot()

# %%
df.head()
# Out:
#                        open    high     low   close   volume  slope
# timestamp
# 2018-05-27 23:45:00  267.10  267.10  267.10  267.10     6222    NaN
# 2018-05-27 23:50:00  267.10  267.95  266.05  266.50   442100  -0.60
# 2018-05-27 23:55:00  266.45  268.15  266.45  268.00   561603   1.50
# 2018-05-28 00:00:00  268.00  271.15  268.00  270.60  1485623   2.60
# 2018-05-28 00:05:00  270.45  270.75  269.55  269.85   537481  -0.75

# %%
df['2018-6-8']
# Out:
#                        open    high     low   close   volume  slope
# timestamp
# 2018-06-08 00:00:00  267.90  268.75  267.60  268.45   214188   0.70
# 2018-06-08 00:05:00  268.30  268.45  267.05  267.35   359561  -1.10
# 2018-06-08 00:10:00  267.40  267.75  267.15  267.65   195650   0.30
# 2018-06-08 00:15:00  267.75  268.20  267.60  268.00   153636   0.35
# 2018-06-08 00:20:00  267.85  268.45  267.60  268.40   136696   0.40
# 2018-06-08 00:25:00  268.35  269.45  268.00  269.15   484017   0.75
# 2018-06-08 00:30:00  269.25  269.40  268.65  268.95   182954  -0.20
# 2018-06-08 00:35:00  269.00  269.00  268.20  269.00   122430   0.05
# 2018-06-08 00:40:00  268.95  269.00  268.70  268.75    97397  -0.25
# 2018-06-08 00:45:00  268.80  270.30  268.75  270.10   439274   1.35
# 2018-06-08 00:50:00  270.10  270.90  270.00  270.45   442112   0.35
# 2018-06-08 00:55:00  270.45  270.85  270.15  270.20   218606  -0.25
# 2018-06-08 01:00:00  270.05  270.25  269.30  269.60   263874  -0.60
# ...

# %%
df.describe()
# Out:
# C:\Installations\Anaconda3\envs\algoT\lib\site-packages\numpy\lib\function_base.py:4291: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#              open        high         low       close        volume  \
# count  754.000000  754.000000  754.000000  754.000000  7.540000e+02
# mean   266.913462  267.276194  266.578714  266.927520  2.397984e+05
# std      2.957946    2.978780    2.953539    2.961768  2.697146e+05
# min    260.700000  261.400000  259.950000  260.600000  2.750000e+02
# 25%    264.650000  264.950000  264.300000  264.600000  1.089980e+05
# 50%    266.575000  266.925000  266.250000  266.575000  1.748360e+05
# 75%    269.300000  269.650000  269.000000  269.337500  2.706560e+05
# max    273.450000  274.650000  273.100000  273.450000  3.008700e+06
#
#             slope
# count  753.000000
# mean     0.007835
# std      0.468039
# min     -2.850000
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max      2.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 754 entries, 2018-05-27 23:45:00 to 2018-06-08 06:00:00
# Data columns (total 6 columns):
# open      754 non-null float64
# high      754 non-null float64
# low       754 non-null float64
# close     754 non-null float64
# volume    754 non-null int64
# slope     753 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 41.2 KB

# %%
import talib

# %%
df.loc['2018-06-08 00:00:00']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-e7143956aa2d> in <module>()
# ----> 1 df.loc['2018-06-08 00:00:00'-'00:05:00']
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df.size
# Out:
# 3770

# %%
df.iloc[1,:]
# Out:
# open         267.10
# high         267.95
# low          266.05
# close        266.50
# volume    442100.00
# Name: 2018-05-27 23:50:00, dtype: float64

# %%
print(list(range(0, 4)))
# Out:
# [0, 1, 2, 3]

# %%
df['delta'] = df['close'].diff()

# %%
RS = df[df['delta'] >= 0]['delta'].sum() / abs(df[df['delta'] < 0]['delta'].sum())
RSI = 100 - (100/(1+RS))
RSI
# Out:
# 51.17905675459632

# %%
up_chng = 0
down_chng = 0
len = df['2018-6-8'].size
slice = df['2018-6-8'].reset_index()
for i in range(0, (len-1)):
    print(slice.iloc[i:i+1, :])
# Out:
#    timestamp   open    high    low   close  volume
# 0 2018-06-08  267.9  268.75  267.6  268.45  214188
#             timestamp   open    high     low   close  volume
# 1 2018-06-08 00:05:00  268.3  268.45  267.05  267.35  359561
#             timestamp   open    high     low   close  volume
# 2 2018-06-08 00:10:00  267.4  267.75  267.15  267.65  195650
#             timestamp    open   high    low  close  volume
# 3 2018-06-08 00:15:00  267.75  268.2  267.6  268.0  153636
#             timestamp    open    high    low  close  volume
# 4 2018-06-08 00:20:00  267.85  268.45  267.6  268.4  136696
#             timestamp    open    high    low   close  volume
# 5 2018-06-08 00:25:00  268.35  269.45  268.0  269.15  484017
#             timestamp    open   high     low   close  volume
# 6 2018-06-08 00:30:00  269.25  269.4  268.65  268.95  182954
#             timestamp   open   high    low  close  volume
# 7 2018-06-08 00:35:00  269.0  269.0  268.2  269.0  122430
# ...

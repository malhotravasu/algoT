# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib.pyplot import matplotlib as plt
from sklearn import preprocessing

# %%
data=pd.read_csv('sentiment_score_new.csv')

# %%
data.set_index('date',inplace=True)

# %%
scaler=preprocessing.MinMaxScaler()

# %%
data.iloc[:,2:]
# Out:
#             content_score    desc_score  title_score
# date
# 2018-10-16       0.281667  3.333333e-02     0.100000
# 2018-10-08       0.312121  2.028409e-01     0.800000
# 2018-10-16       0.129167  3.621212e-01     0.000000
# 2018-10-08       0.468182  2.028409e-01     0.800000
# 2018-10-21       0.350000  1.272727e-01     0.000000
# 2018-09-24      -0.001705  7.930164e-18     0.050000
# 2018-10-06       0.250000  2.715909e-01     0.000000
# 2018-10-08       0.016667  1.363636e-01     0.000000
# 2018-10-01       0.078788  5.000000e-02     0.000000
# 2018-09-22       0.100000  4.181818e-01     0.568182
# 2018-10-18       0.075000  7.500000e-02    -0.800000
# 2018-10-09       0.054545  5.681818e-01     1.000000
# 2018-10-06       0.143939  2.257576e-01     0.000000
# 2018-10-11       0.147143  2.000000e-01     0.000000
# 2018-09-28       0.500000  5.000000e-01     0.136364
# 2018-10-17       0.472000 -1.333333e-01     0.000000
# 2018-10-08       0.208144  1.000000e-01     0.000000
# ...

# %%
#plt.figure(figsize=(20,10))
data.describe()
# Out:
#        content_score   desc_score  title_score
# count    1000.000000  1000.000000  1000.000000
# mean        0.044592     0.115351     0.085258
# std         0.253861     0.196312     0.252559
# min        -0.750000    -0.700000    -1.000000
# 25%        -0.031250     0.000000     0.000000
# 50%         0.077619     0.092032     0.000000
# 75%         0.199048     0.214026     0.160000
# max         0.700000     1.000000     1.000000

# %%
temp=data.copy()

# %%
temp.content_score=preprocessing.scale(temp.content_score)
temp.desc_score=preprocessing.scale(temp.desc_score)
temp.title_score=preprocessing.scale(temp.title_score)


temp_data=scaler.fit_transform(pd.DataFrame(data.desc_score))
newtmp=pd.DataFrame(temp_data)
newtmp.plot()

# %%
data.plot()

# %%
temp.plot()

# %%
data.content_score.plot()

# %%
data.desc_score.plot()
newtmp.plot()

# %%
data.title_score.plot()
